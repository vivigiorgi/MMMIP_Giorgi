# %%
from skimage.io import imread
import numpy as np
from scipy.fftpack import dct, idct
from scipy.signal import convolve2d
from matplotlib import pyplot as plt
import time
import math
from google.colab import drive

# %%
drive.mount('/content/drive')
rootfolder = '/content/drive/MyDrive'
# Out:
# Mounted at /content/drive

# %% [markdown]
# Definition of dct2 and idct2 (they are not builtin functions)

# %%
def dct2(s):
    return dct(dct(s.T, norm='ortho').T, norm='ortho')


def idct2(x):
    return idct(idct(x.T, norm='ortho').T, norm='ortho')

# %% [markdown]
# Useful function for plot the 2D DCT dictionary

# %%
def get_dictionary_img(D):
    M = D.shape[0]
    p = int(round(np.sqrt(M)))
    bound = 2
    img = np.ones((p*p+bound*(p-1), p*p+bound*(p-1)))
    for i in range(M):
        m = np.mod(i, p)
        n = int((i-m)/p)
        m = m * p + bound * m
        n = n * p + bound * n
        atom = D[:, i].reshape((p, p))
        if atom.min() < atom.max():
            atom = (atom - atom.min()) / (atom.max() - atom.min())
        img[m: m + p, n: n + p] = atom

    return img

# %% [markdown]
# Load the image and rescale it in $[0,1]$

# %%
img = imread(f'{rootfolder}/data/checkerboard.png') / 255
#img = imread(f'{rootfolder}/data/cameraman.png') / 255
#img = imread(f'{rootfolder}/data/Lena512.png') / 255

imsz = img.shape

# patch size
p = 8

# number of elements in the patch
M = p ** 2

# %% [markdown]
# Create the noisy image
# ----------------------------

# %%
sigma_noise = 20/255
eta= np.random.normal(loc= 0,scale= sigma_noise, size= img.shape)
noisy_img = img + eta

# %% [markdown]
# Compute the psnr of the noisy input

# %%
mse_noisy = ((img-noisy_img)**2).mean()
psnr_noisy= 10*math.log10(1/mse_noisy)

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original image')

ax[1].imshow(noisy_img, cmap='gray')
ax[1].set_title(f'Noisy image, PSNR = {psnr_noisy:.2f}')
# Out:
# Text(0.5, 1.0, 'Noisy image, PSNR = 22.08')

# %% [markdown]
# Denoising by smoothing
# ----------------------
# Define a filter that by convolution returns the average over a 5x5 region

# %%
h = np.ones((5, 5))/25

# %% [markdown]
# Compute the convolution of the noisy image against the averaging filter (use the ``convolve2d`` function with the ``same`` padding)

# %%
img_hat_conv = convolve2d(noisy_img,h,mode='same')

# %% [markdown]
# Compute the psnr of the estimated image

# %%
psnr_hat_conv = 10*math.log10(1/((img_hat_conv-noisy_img)**2).mean())
plt.figure(figsize=(10, 10))
plt.imshow(img_hat_conv, cmap='gray')
plt.title(f'Estimated Image (conv),\nPSNR = {psnr_hat_conv:.2f}')
# Out:
# Text(0.5, 1.0, 'Estimated Image (conv),\nPSNR = 13.84')

# %% [markdown]
# DCT denoising
# -------------
# Generate the DCT basis

# %%
D = np.zeros((M, M))
cnt = 0
for i in range(p):
    for j in range(p):
        a = np.zeros((p,p)) 
        a[i,j] = 1 
        D[:, cnt] = idct2(a).flatten() 
        cnt = cnt + 1

# %%
D_img = get_dictionary_img(D)
plt.figure(figsize=(8, 8))
plt.imshow(D_img, cmap='gray')

# %% [markdown]
# Denoising: set parameters and initialize the variables

# %%
# initialize the estimated image
img_hat = np.zeros_like(img)

# initialize the weight matrix
weights = np.zeros_like(img)

# set the threshold for the Hard Thresholding
tau = 3 * sigma_noise 
# tau= sigma_noise * math.sqrt(2*math.log(p^2))

# define the step (=p for non overlapping paches)
STEP = p

# %% [markdown]
# Perform the denoising pathwise

# %%
for i in range(0, imsz[0] - p + 1, STEP):
    for j in range(0, imsz[1] - p + 1, STEP):
        # extrach the patch with the top left corner at pixel (ii, jj)
        s = noisy_img[i:i+p,j:j+p].flatten()

        # compute the representation w.r.t. the 2D DCT dictionary
        x = (D.T@s).reshape((p,p))

        # perform the hard thresholding (do not perform HT on the DC!)
        x_HT = x.copy()
        x_HT[np.abs(x_HT)<=tau] = 0
        x_HT[0,0]=x[0,0] 

        # perform the reconstruction
        s_hat = idct2(x_HT)

        # compute the weight for the reconstructed patch
        nnz_patch = np.count_nonzero(x_HT)
        if nnz_patch==0:
          nnz_patch = 1
        w = 1/nnz_patch

        # put the compressed patch into the compressed image using the computed weight
        # UPDATE img_hat
        img_hat[i:i+p,j:j+p] += s_hat * w

        # store the weight of the current patch in the weight matrix
        # UPDATE weights
        # serve fare += perché nel caso di step 1 ho anche sovrapposizione e devo tenere conto di tutti i filtri lì intorno
        # nel caso di STEP = p non ho sovrapposizione quindi non ce n'è bisogno
        weights[i:i+p,j:j+p] += np.full((p,p),w)

# %% [markdown]
# Normalize the estimated image with the computed weights

# %%
img_hat = img_hat / weights

# %% [markdown]
# Compute the psnr of the estimated image

# %%
psnr_hat = 10*math.log10(1/((img_hat-noisy_img)**2).mean())
plt.figure(figsize=(10,10))
plt.imshow(img_hat, cmap='gray')
plt.title(f'Estimated Image,\nPSNR = {psnr_hat:.2f}')
# Out:
# Text(0.5, 1.0, 'Estimated Image,\nPSNR = 22.29')

# %% [markdown]
# Noise estimation
# ----------------
# Define the horizontal derivative filter

# %%
h = np.array([[-1,1]])
# h is a row vector

# %% [markdown]
# Convolve the noisy image and the filter

# %%
differences = convolve2d(noisy_img,h,mode='same')

# %% [markdown]
# Compute sigma as the empirical std

# %%
sigma_hat_emp = np.std(differences)/np.sqrt(2)

# %% [markdown]
# Use MAD to estimate the noise level sigma

# %%
from scipy import stats
sigma_hat = stats.median_abs_deviation(differences,axis=None)/(np.sqrt(2)*0.67449)

# %%
print(f'sigma: {sigma_noise:.3f}, sigma_hat (empirical std): {sigma_hat_emp:.3f}, sigma_hat (MAD): {sigma_hat:.3f}')
# Out:
# sigma: 0.078, sigma_hat (empirical std): 0.170, sigma_hat (MAD): 0.085
